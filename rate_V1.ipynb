# %%
import pandas as pd

datas = pd.read_csv("rate_datas_all.csv", encoding="big5")

# %%
datas
# Out:
#               日期  美元／新台幣   人民幣／新台幣    歐元／美元    美元／日幣    英鎊／美元    澳幣／美元  \
# 0     2015/01/05  32.007         -  1.19425  120.555  1.52865  0.80550
# 1     2015/01/06  31.998         -  1.19555  119.115  1.52595  0.81380
# 2     2015/01/07  31.972         -  1.18755  118.995  1.51385  0.80740
# 3     2015/01/08  31.990         -  1.18200  119.720  1.50835  0.81060
# 4     2015/01/09  31.957         -  1.18105  119.275  1.50975  0.81390
# ...          ...     ...       ...      ...      ...      ...      ...
# 2579  2025/08/04  29.918  4.168415  1.15620  147.970  1.32760  0.64735
# 2580  2025/08/05  29.927  4.160062  1.15440  147.450  1.32745  0.64560
# 2581  2025/08/06  29.990   4.16912  1.15820  147.625  1.32980  0.64925
# 2582  2025/08/07  29.820  4.153151  1.16835  146.995  1.33700  0.65320
# 2583  2025/08/08  29.855  4.155249  1.16615  147.215  1.34500  0.65335
#
#         美元／港幣   美元／人民幣    美元／南非幣    紐幣／美元
# 0     7.75655  6.23735  11.73525        -
# ...

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['mingliu', 'Microsoft JhengHei']
plt.rcParams['axes.unicode_minus'] = False

datas.plot(x="日期", y="美元／新台幣" , kind='line', figsize=(12, 5))
# Out:
# <Axes: xlabel='日期'>
